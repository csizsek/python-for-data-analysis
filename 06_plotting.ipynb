# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
import matplotlib.pyplot as plt

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
fig1 = plt.plot()

# %%
fig2, axs2 = plt.subplots(2, 2)

# %%
plt.plot(randn(100).cumsum(), 'b-')

# %%
plt.hist(randn(1000), bins=20, color='r')
# Out:
# (array([   1.,    2.,   10.,   14.,   35.,   46.,   90.,  105.,  124.,
#          110.,  139.,  113.,   62.,   60.,   44.,   24.,   10.,    5.,
#            4.,    2.]),
#  array([-3.19705035, -2.87131267, -2.54557498, -2.2198373 , -1.89409961,
#         -1.56836193, -1.24262424, -0.91688656, -0.59114887, -0.26541119,
#          0.0603265 ,  0.38606418,  0.71180187,  1.03753955,  1.36327724,
#          1.68901492,  2.01475261,  2.34049029,  2.66622798,  2.99196566,
#          3.31770335]),
#  <a list of 20 Patch objects>)

# %%
plt.scatter(np.arange(30), np.arange(30) + 3*randn(30), color='g')

# %%
x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)

y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

plt.subplot(2, 1, 1, sharex=True)
plt.plot(x1, y1, 'ko-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')

plt.subplot(2, 1, 2)
plt.plot(x2, y2, 'r.-')
plt.xlabel('time (s)')
plt.ylabel('Undamped')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-ea6f7a720f41> in <module>()
#       5 y2 = np.cos(2 * np.pi * x2)
#       6
# ----> 7 plt.subplot(2, 1, 1, sharex=True)
#       8 plt.plot(x1, y1, 'ko-')
#       9 plt.title('A tale of 2 subplots')
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/pyplot.pyc in subplot(*args, **kwargs)
#     895
#     896     fig = gcf()
# --> 897     a = fig.add_subplot(*args, **kwargs)
#     898     bbox = a.bbox
#     899     byebye = []
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/figure.pyc in add_subplot(self, *args, **kwargs)
#     912                     self._axstack.remove(ax)
#     913
# --> 914             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#     915
#     916         self._axstack.add(key, a)
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/axes.pyc in __init__(self, fig, *args, **kwargs)
#    9257
#    9258         # _axes_class is set in the subplot_class_factory
# -> 9259         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#    9260
#    9261     def __reduce__(self):
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/axes.pyc in __init__(self, fig, rect, axisbg, frameon, sharex, sharey, label, xscale, yscale, **kwargs)
#     426         self._sharey = sharey
#     427         if sharex is not None:
# --> 428             self._shared_x_axes.join(self, sharex)
#     429             if sharex._adjustable == 'box':
#     430                 sharex._adjustable = 'datalim'
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/cbook.pyc in join(self, a, *args)
#    1642
#    1643         for arg in args:
# -> 1644             set_b = mapping.get(ref(arg))
#    1645             if set_b is None:
#    1646                 set_a.append(ref(arg))
#
# TypeError: cannot create weak reference to 'bool' object
